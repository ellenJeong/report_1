# %%
from urllib.request import urlopen

url="https://www.naver.com"
html=urlopen(url)

print(html.read())
# Out:
# b'\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\x
# ...

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=c2a5bceeb53a3b8644335b9b813551a44bcaa359af82bf099e15762e27011d8a
#   Stored in directory: c:\users\m\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4

# %%
bs_obj = bs4.BeautifulSoup(html, "html.parser")

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

print(bs_obj)
# Out:
# <!DOCTYPE html>
# ...

# %%
del bs_obj.findAll("div")[0].text.split(" ")[-1]

# %%
var_1=bs_obj.findAll("div")[0].text.split(" ")

# %%
del var_1[0]
del var_1[-1]
var_1
# Out:
# ['타임스퀘어', '바로가기', '쇼핑캐스트']

# %%
import bs4
html_str="<html><div>hello</div></html>"
bs_obj=bs4.BeautifulSoup(html_str,"html.parser")

# %%
print(type(bs_obj))
print(bs_obj)
print(bs_obj.find("div").text)
# Out:
# <class 'bs4.BeautifulSoup'>
# <html><div>hello</div></html>
# hello

# %%
html_str="""
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li >welcome</li>
        </ul>
    </body>
</html>
"""
bs_obj=bs4.BeautifulSoup(html_str,"html.parser")
ul=bs_obj.find("ul")
a_1=ul.findAll("li")
var_2 = []
for i in a_1:
    var_2.append(i.text)
var_2
# Out:
# ['hello', 'bye', 'welcome']

# %%
import re

# %%
var_3=var_2.replace("\n"," ")
var4=var_3.split(" ")

# %%
del var4[0]

# %%
del var4[-1]

# %%
var4
# Out:
# ['hello', 'bye', 'welcome']

# %%
# Out:
# <li>hello</li>

# %%
import bs4

html_str="""
<html>
     <body>
         <ul>
             <li>hello</li>
             <li>bye</li>
             <li>welcome</li>
         </ul>
     </body>
</html>     
"""
bs_obj=bs4.BeautifulSoup(html_str,"html.parser")

ul=bs_obj.find("ul")
ul
# Out:
# <ul>
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
lis=ul.findAll("li")
for i in lis :
    print(i.text)
# Out:
# hello
# bye
# welcome

# %%
import bs4

html_str="""
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str,"html.parser")

ul = bs_obj.find("ul")
lis = ul.findAll("li")
print(lis)
lis[0]
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]
# <li>hello</li>

# %%
import bs4

html_str="""
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str,"html.parser")

ul = bs_obj.find("ul")
lis = ul.findAll("li")
print(lis[1])
# Out:
# <li>bye</li>

# %%
import bs4

html_str="""
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str,"html.parser")

ul = bs_obj.find("ul")
lis = ul.findAll("li")
print(lis[1].text)
# Out:
# bye

# %%
import bs4

html_str="""
<html>
    <body>
        <ul class="greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
        <ul class="reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str,"html.parser")

ul = bs_obj.find("ul")
print(ul)
# Out:
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
import bs4

html_str="""
<html>
    <body>
        <ul class="greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
        
        <ul class="reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
<html>
    
"""

bs_obj=bs4.BeautifulSoup(html_str,"html.parser")

ul=bs_obj.find("ul",{"class":"reply"})
lis=ul.findAll("li")

for i in lis:
    print(i.text)
# Out:
# ok
# no
# sure

# %%
import bs4

html_str="""
<html>
    <body>
        <ul class="ko">
            <li>
                <a href="https://www.naver.com">네이버</a>
            </li>
            <li>
                <a href="https://www.daum.net">다음</a>
            </li>
         </ul>
         <ul class="sns">        
            <li>
                <a href="https://www.google.com">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com">페이스북</a>
            </li>
        </ul>
    </body>
</html>
"""
bs_obj=bs4.BeautifulSoup(html_str,"html.parser")
atag=bs_obj.find("a")
print(atag)
# Out:
# <a href="https://www.naver.com">네이버</a>

# %%
import bs4

html_str="""
<html>
    <body>
        <ul class="ko">
            <li>
                <a href="https://www.naver.com/">네이버</a>
            </li>
            <li>
                <a href="https://www.daum.net/">다음</a>
            </li>
        </ul>
        <ul class="sns">
            <li>
                <a href="https://www.google.com/">구글</a>
            </li>
            <li>
                <a href="https://www.facebook.com/">페이스북</a>
            </li>
        </ul>
    </body>
</html>
"""
bs_obj = bs4.BeautifulSoup(html_str,"html.parser")

atag = bs_obj.find("a")
print(atag['href'])
# Out:
# https://www.naver.com/

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

print(html.read())
# Out:
# b'\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\x
# ...

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

print(bs_obj)
# Out:
# <!DOCTYPE html>
# ...

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

top_right = bs_obj.find("div", {"class":"service_area"})
print(top_right)
# Out:
# <div class="service_area">
# <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>

# %%
<a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# Out:
#   File "C:\Users\M\AppData\Local\Temp/ipykernel_11308/2350941048.py", line 1
#     <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
#     ^
# SyntaxError: invalid syntax

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

top_right = bs_obj.find("div", {"class":"service_area"})
first_a = top_right.find("a")
print(first_a.text)
# Out:
# 네이버를 시작페이지로

# %%
<div class="service_area">
<a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
<i class="sa_bar"></i>
<a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
<a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
</div>

# %%
import urllib.request

url = "https://www.naver.com"
html = urllib.request.urlopen(url)

bs_obj = bs4.BeautifulSoup(html, "html.parser")

div = bs_obj.find("div", {"class":"service_area"})
a_1=div.findAll("a")
var_2=[]
for i in a_1 :
    print(i.text)
    var_2.append(i.text)
var_2[0]
# Out:
# 네이버를 시작페이지로
# 쥬니어네이버
# 해피빈
# '네이버를 시작페이지로'

# %%
import urllib.request

url="https://www.naver.com"
html=urllib.request.urlopen(url)

bs_obj=bs4.BeautifulSoup(html,"html.parser")
div=bs_obj.find("div",{"class":"list_theme_wrap"})
a_1=div.findAll("a")
a_1
var_1=[]
for i in a_1:
    var_1.append(i.text)
var_1
var_2=[]
for i in var_1:
    var_2.append(re.sub("\n","",i))
var_2
# Out:
# ['',
#  ' 패션뷰티루나 라이트 쿠션루나 컴피 라이트 쿠션/ 컴피 라이트 파운데이션/ 컴피 투명 피니쉬 파우더 #요즘아이돌베이스 #이나겸쿠션 베이스 장인 루나(LUNA)에서 새롭게 출시한 컴피 라이트 쿠션, 파운데이션, 파우더! 요즘아이돌의 메이크업을 담당하는 메이크업아티스트 이나겸님과의 콜라보로 탄생한 루나 신제품 컴피라이트 쿠션, 파운데이션 소개해드려요. 그리고 같은 컴피 라인인 컴피 투3주일 전보거',
#  '',
#  ' 패션뷰티바닐라코 바비 콜라보여러분 일단 박수부터 치고 갈까요? 짝짝짝! 바닐라코 X 바비 콜라보 진짜 역대급이야 저 눈물날정도로 너무 이뻐서 황홀황홀! 어릴적 동심까지 불러일으키는 핑크핑크 러블리한 두 콜라보 전제품 가져왔는데 우리 함께 만나볼까요!? 하하 여러분 제가 얼마나 진심이냐면요 온종일 스티커 붙이기하듯 누끼따서 바비와 바닐라코의 콜라보를 즐겼답니다 진짜 이렇게 바비들 데려1개월 전다지',
#  '',
#  ' 패션뷰티롬앤 브로우 카라안녕 여러분 ! 뷰스타 물보라에요 ;) 색조맛집 롬앤에서 출시한 한올라인의 브로우카라와 브로우픽서 두 가지 제품을 가지고 와봤어요, 요즘 트렌드인 한올한올 결 살린 눈썹을 연출하기 위해서는 픽서의 역할이 정말 중요하잖아요! 오늘은 내가 원하는대로 딱 픽싱되어 한 끗 차이로 달라진 무드를 연출해줄 롬앤 한올 브로우 픽서와 모발과 컬러를 맞추며 원하는 컬러 그3주일 전물보라',
#  '',
#  ' 패션뷰티릴리바이레드 립 펜슬안녕하세요! E양입니다 요즘 오버립에 진심이신 분들 많죵? 저는 입술이 매우 두껍지만,, 음영 넣는 게 넘 재밌더라고요!!! 입매까지 예뻐지는 오버립 메이크업 이번에 출시된 릴리바이레드 스마일리 립 블렌딩 스틱으로 보여드릴게용! 프로모션 소식도 있으니깐 참고해서 득템하세요!! 진쨔 좋음.. 스마일리 립 블렌딩 스틱 12,000원 / 0.8g / 23년 3월3주일 전E양']

# %%
var_3=[]
for i in range(len(var_2)):
    if(i%2==0):
        pass
    else:
        var_3.append(var_2[i])
var_3
# Out:
# [' 패션뷰티루나 라이트 쿠션루나 컴피 라이트 쿠션/ 컴피 라이트 파운데이션/ 컴피 투명 피니쉬 파우더 #요즘아이돌베이스 #이나겸쿠션 베이스 장인 루나(LUNA)에서 새롭게 출시한 컴피 라이트 쿠션, 파운데이션, 파우더! 요즘아이돌의 메이크업을 담당하는 메이크업아티스트 이나겸님과의 콜라보로 탄생한 루나 신제품 컴피라이트 쿠션, 파운데이션 소개해드려요. 그리고 같은 컴피 라인인 컴피 투3주일 전보거',
#  ' 패션뷰티바닐라코 바비 콜라보여러분 일단 박수부터 치고 갈까요? 짝짝짝! 바닐라코 X 바비 콜라보 진짜 역대급이야 저 눈물날정도로 너무 이뻐서 황홀황홀! 어릴적 동심까지 불러일으키는 핑크핑크 러블리한 두 콜라보 전제품 가져왔는데 우리 함께 만나볼까요!? 하하 여러분 제가 얼마나 진심이냐면요 온종일 스티커 붙이기하듯 누끼따서 바비와 바닐라코의 콜라보를 즐겼답니다 진짜 이렇게 바비들 데려1개월 전다지',
#  ' 패션뷰티롬앤 브로우 카라안녕 여러분 ! 뷰스타 물보라에요 ;) 색조맛집 롬앤에서 출시한 한올라인의 브로우카라와 브로우픽서 두 가지 제품을 가지고 와봤어요, 요즘 트렌드인 한올한올 결 살린 눈썹을 연출하기 위해서는 픽서의 역할이 정말 중요하잖아요! 오늘은 내가 원하는대로 딱 픽싱되어 한 끗 차이로 달라진 무드를 연출해줄 롬앤 한올 브로우 픽서와 모발과 컬러를 맞추며 원하는 컬러 그3주일 전물보라',
#  ' 패션뷰티릴리바이레드 립 펜슬안녕하세요! E양입니다 요즘 오버립에 진심이신 분들 많죵? 저는 입술이 매우 두껍지만,, 음영 넣는 게 넘 재밌더라고요!!! 입매까지 예뻐지는 오버립 메이크업 이번에 출시된 릴리바이레드 스마일리 립 블렌딩 스틱으로 보여드릴게용! 프로모션 소식도 있으니깐 참고해서 득템하세요!! 진쨔 좋음.. 스마일리 립 블렌딩 스틱 12,000원 / 0.8g / 23년 3월3주일 전E양']

# %%
import urllib.request
import bs4

# %%
url="https://www.naver.com/"
html=urllib.request.urlopen(url)

# %%
bs_obj=bs4.BeautifulSoup(html,"html.parser")

# %%
div=bs_obj.find("div",{"class":"group_nav"})
print(div)
# Out:
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# ...

# %%
div_1=[]
for i in div:
    div_1.append(i)
div_1[1]
# Out:
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# ...

# %%
div_2=[]
for i in range(len(div_1)):
    if(i%2==0):
        pass
    else:
        div_2.append(div_1[i])
div_3=div_2[0]
div_3
div_4=[]
for i in div_3:
    div_4.append(i.find("a"))
div_4
div_5=[]
for i in range(len(div_4)):
    if(i%2==0):
        pass
    else:
        div_5.append(div_4[i])
div_5    
for i in range(len(div_5)):
    print(div_5[i].text)
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# 쇼핑LIVE
# Pay
# TV

# %%
div=bs_obj.find("div",{"class":"group_nav"})
print(div)
# Out:
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# ...

# %%
alis=div.findAll("a")
print(alis)
# Out:
# [<a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>, <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a>, <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a>, <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a>, <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a>, <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a>, <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a>, <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>, <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a>, <a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a>, <a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">증권</a>, <a class
# ...

# %%
for i in range(len(alis)):
    print(alis[i].text)
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# 쇼핑LIVE
# Pay
# TV
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 도서
# 웹툰
# 더보기
# 서비스 전체보기
# 메뉴설정
# 초기화
# 저장

# %%
<div class="r_news_tx">
					<span class="r_news_tit"><strong>김기현 “‘돈봉투 의혹’ 민주당 전당대회, ‘쩐당대회’”</strong></span>
					<em class="r_press"><b>경향신문</b></em><span class="r_ico_b r_modify "><b>25분전</b></span>
				</div>

# %%
import urllib.request
import bs4

# %%
url="http://news.naver.com/"
html=urllib.request.urlopen(url)

bs_obj=bs4.BeautifulSoup(html,"html.parser")

print(bs_obj)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title id="browserTitleArea">네이버 뉴스</title>
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
# <script>
# 		var g_ssc = 'news.v3_media' || null;
# 		</script>
# ...

# %%
div=bs_obj.findAll("div",{"class":"cjs_news_tw"})
div_2=[]
for i in div:
    div_2.append(i.find("div",{"class":"cjs_t"}).text)
div_2[0]
# Out:
# '공공성 훼손 vs 지나친 차별...말 많은 대학 ‘학점은행제’ [로컬이슈]'

# %%
<div class="cjs_journal_wrap _item_contents">
                    
                    
                    <a href="https://n.news.naver.com/article/082/0001207285?cds=news_media_pc&amp;type=editn" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
                        <div class="cjs_news_mw">
                            <img loading="lazy" src="https://mimgnews.pstatic.net/image/origin/082/2023/04/13/1207285.jpg?type=nf264_176&amp;ut=20230413113101" width="100%" alt="" onerror="showNoImage(this)">
                            
                        </div>
                        <div class="cjs_news_tw">
                            
                                
                                
                                    <div class="cjs_t">“세상 마약 다 취급”…수감 중 ‘전세계’ 여전히 암흑세계서 ‘큰손’</div>
                                    
                                        
                                        
                                            <p class="cjs_d">“세상에 존재하는 마약은 전부 다 취급한다.” 텔레그램 닉네임 ‘마약왕 전세계’로 국내 마약 유통 총책으로 불리는 박왕열(45) 씨가 국내 마약 판매책들에게 한 말이다. 한국인 3명을 살해해 60년을 선고받고 필리핀</p>
                                        
                                    
                                
                            
                        </div>
                    </a>
                </div>

# %%
<div id="newsct_article" class="newsct_article _article_body">
		<div id="dic_area" class="go_trans _article_content" style="-webkit-tap-highlight-color: rgba(0,0,0,0)">
			<strong class="media_end_summary">전세계 통해 국내 마약 유통한 3명 구속<br>밀반입돼 있던 마약 던지기, 또 던지기<br>엑스터시 100정 등 국내 판매책에 넘겨<br>수감 중 휴대전화 사용 “조사해봐야 확인”</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP is_long">
	<div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
		<img id="img1" class="_LAZY_LOADING" src="https://imgnews.pstatic.net/image/082/2023/04/13/0001207285_001_20230413113101142.jpg?type=w647">
	</div>
</div><em class="img_desc">마약왕 전세계와 텔레그램 대화 내용. 경남경찰청 제공</em></span><br><br>“세상에 존재하는 마약은 전부 다 취급한다.”<br><br>텔레그램 닉네임 ‘마약왕 전세계’로 국내 마약 유통 총책으로 불리는 박왕열(45) 씨가 국내 마약 판매책들에게 한 말이다. 한국인 3명을 살해해 60년을 선고받고 필리핀 교도소에 수감된 박 씨는 여전히 국내 마약 공급·유통에 ‘큰손’으로 활동하고 있다.<br><br>경남경찰청은 마약류 관리에 관한 법률 위반 혐의로 20대 A 씨 등 3명을 구속했다고 13일 밝혔다. 이들은 2023년 1월부터 2월 사이 소위 던지기(은밀한 장소 등에 마약을 숨기면 구매자가 찾아가는) 수법으로 엑스터시 100정과 필로폰 10g을 국내 중간 판매책 등에게 두 차례에 걸쳐 600만 원(도매가)에 판 혐의를 받고 있다. 시중 판매 시 소매가격은 약 5300만 원 정도로 추정된다.<br><br>필리핀 교도소에 수감돼 있던 박 씨로부터 엑스터시 1470여 정 등 마약을 확보한 것으로 드러났다. 이들 3명에게도 ‘좌표(은밀한 장소)’를 찍고 던지기하는 수법으로 전달했다. 경찰은 2~3일 만에 공급된 것으로 보아 이미 국내로 밀반입돼 보관 중이던 마약이 있는 것으로 보고 있다.<br><br>지난해 12월 A 씨가 필리핀 교도소를 찾아 박 씨를 면회, 범행을 공모했다. 애초 지인 사이여서 면회가 가능했던 것으로 파악된다.<br><br>텔레그램 메시지와 영상통화 등으로 지속해서 소통하며 범행 지시를 주고받았다. “난 물건 10개씩 안 팔어, 기본 키로 이상 주문만 받아” “품목은, 세상의 존재하는 마약 전부다” 등 대화가 오갔다.<br><br>교도소에 수감 중인 박 씨가 휴대전화 등 전자기기 사용할 수 있었던 점에 대해 경찰은 “조사를 해봐야 알 수 있겠다”고 말했다. 현재 박 씨에 대해서는 인터폴 적색수배 조치하고, 법무부·경찰청과 협조해 국내 송환 절차를 밟고 있다.<br><br><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP is_long">
	<div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a2">
		<img id="img2" class="_LAZY_LOADING" src="https://imgnews.pstatic.net/image/082/2023/04/13/0001207285_002_20230413113101251.jpg?type=w647">
	</div>
</div><em class="img_desc">마약왕 전세계와 텔레그램 메시지 내용. 경남경찰청 제공</em></span><br><br>앞서 경남경찰청은 남양유업 창업주 외손녀 황하나 씨 등 유명인에게 마약을 공급한 ‘바티칸 킹덤’ B 씨(20대)를 검거하면서 이미 박 씨를 국내로 송환해달라고 요청해둔 상황이었다. 또 2016년 10월께 필리핀 팜팡가주의 한 마을 인근 사탕수수밭에서 한국인 남녀 3명을 총살해 시체를 유기한 혐의(다량살인)로 지난해 5월 장기 60년(단기 57년 4개월) 징역형을 확정한 바 있다.<br><br>현재도 텔레그램 대화명을 바꿔가며 국내로 마약을 유통하고 있는 것으로 확인됐다.<br><br>경찰 관계자는 “조직적이고 지능화되는 마약류 범죄에 대한 수사기법 개발 등을 통해 지속적으로 추적·검거할 예정이다”고 말했다.<br><br>
		</div>
	</div>

# %%
# <div class="cjs_journal_wrap _item_contents">  => 여기에서 a 태그 찾기
# a 태그에서 링크만 텍스트로 추출할 것
# 링크를 urlopen에 넣고 => html 이후에는 동일
# html에서 찾아야 하는 것이 <div id="newsct_article" class="newsct_article _article_body">

# %%
url="http://news.naver.com/"
html=urllib.request.urlopen(url)

bs_obj=bs4.BeautifulSoup(html,"html.parser")

print(bs_obj)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title id="browserTitleArea">네이버 뉴스</title>
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
# <script>
# 		var g_ssc = 'news.v3_media' || null;
# 		</script>
# ...

# %%
div=bs_obj.findAll("div",{"class":"cjs_journal_wrap _item_contents"})
div
div_1=[]
for i in div:
    div_1.append((i.find("a")['href']))
div_2=div_1[0]

# %%
html=urllib.request.urlopen(div_2)
bs_obj=bs4.BeautifulSoup(html,"html.parser")

print(bs_obj)
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="Python-urllib/3.9" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="대마도 최초의 둘레길 한국인이 만들었다" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/article/094/0000010836" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/094/2023/04/13/0000010836_001_20230413092301175.jpg?type=w800" property="og:image"/>
# <meta content="일본 대마도로 향하는 바닷길이 3년 만에 다시 열렸다. 관광객의 발길이 끊겼던 이 시기에 대마도에는 새로운 둘레길이 생겨났다. 사람들에게 잊혀진 옛길들에 새 생명을 불어넣은 주인공은 한국인 고광용씨. 대마도의 자연에" property="og:description"/>
# <meta content="월간 산 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="대마도 최초의 둘레길 한국인이 만들었다" name="twitter:title"/>
# ...

# %%
<div id="newsct_article" class="newsct_article _article_body">

# %%
div=bs_obj.findAll("div",{"class":"newsct_article _article_body"})
div[0].text
# Out:
# "\n\n총 105km 7개 구간 트레킹… 둘레길 걸으며 보는 대마도의 명소소소한 대마도의 매력 느낄 수 있어\n\n\n\n일본 대마도로 향하는 바닷길이 3년 만에 다시 열렸다. 관광객의 발길이 끊겼던 이 시기에 대마도에는 새로운 둘레길이 생겨났다. 사람들에게 잊혀진 옛길들에 새 생명을 불어넣은 주인공은 한국인 고광용씨. 대마도의 자연에 매료된 고씨는 2017년 대마도로 이주을 결심했다. 히타카쓰에 새 보금자리를 틀고 식당과 민박을 운영하며, 남는 시간엔 대마도 북섬의 숨겨진 도로를 찾아 헤맸다. 그가 찾은 대마도의 진짜 매력은 전형적인 관광 명소가 아닌 평범한 길 위에 있었다. 대마도로부터 받은 '여유'라는 선물을 다른 이들에게 전하고 싶었던 그는 숨겨진 점들을 이어 둘레길이라는 선을 만들기로 결심했다. 둘레길은 총 105km로 평균 15km의 7개 구간으로 이루어져 있다. 대마도의 푸른 숲과 산 그리고 바다를 한 번에 조망할 수 있는 코스다. 또한 일반 관광지가 아닌 지역 마을을 지나고 그곳에 머물며 지역민과 긴밀히 교류할 수 있도록 한 것이 핵심. 그들이 말하는 둘레길의 핵심은 '힐링'이다. 여유로운 마음으로 가진 걸 비워내며 걷는 길이다. \n\n\n\n히타카쓰에서 맞이하는 일출１구간 히타카쓰 - 이즈미 - 토요, 약 12km 주요 명소 : 미우다해변, 토노사키국립공원, 곤겐산 1구간은 대마도를 가장 먼저 만나는 히타카쓰에서 시작한다. 곤겐산을 경유하는 산길을 이용하거나, 니시도마리해수욕장을 지나는 바닷길 중 본인의 취향에 맞는 코스를 선택할 수 있다. 기자가 방문했던 지난 3월 초엔 태풍의 영향으로 곤겐산 등산로가 폐쇄되어 바닷길로 갈 수밖에 없었다. 하지만 아쉬움도 잠시. 깊이를 가늠할 수 없는 투명한 바닷물이 미련을 씻어 내린다. 니시도마리해수욕장을 지나 살짝 코스를 이탈해 곤겐산전망대로 향한다. 전망대에서는 미우다해변을 내려다볼 수 있다. 차량으로 이동할 수 있어 일반 관광객도 많이 찾는 곳이다. 하지만 높게 자란 나무 때문에 마을 전경과 토
# ...

# %%
import os, codecs, re, datetime, requests
import urllib.request as ur
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
url = "https://news.naver.com"
driver = webdriver.Chrome(r'C:\Users\M\Documents\chromedriver_win32\chromedriver.exe')
driver.implicitly_wait(2)
driver.get(url)
html = driver.page_source
bs_obj = bs(html,'html.parser')
div=bs_obj.find("div",{"class":"r_news_tx"})
print(div)
# Out:
# C:\Users\M\AppData\Local\Temp/ipykernel_10944/1537770505.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\M\Documents\chromedriver_win32\chromedriver.exe')
# None

# %%
pip install webdriver_manger
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement webdriver_manger (from versions: none)
# ERROR: No matching distribution found for webdriver_manger

# %%
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20220/3760988781.py in <module>
# ----> 1 from webdriver_manager.chrome import ChromeDriverManager
#
# ModuleNotFoundError: No module named 'webdriver_manager'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import subprocess
from selenium.webdriver.chrome.service import Service


subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chromeCookie"')
url = "https://news.naver.com"


option = Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
driver = webdriver.Chrome(r'C:\Users\M\Documents\chromedriver_win32\chromedriver.exe')
driver.maximize_window()
driver.get(url)
# Out:
# C:\Users\M\AppData\Local\Temp/ipykernel_10944/3620644762.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\M\Documents\chromedriver_win32\chromedriver.exe')

# %% [markdown]
# del var_1[0]

# %% [markdown]
# ### 트렌드쇼핑 버튼 찾기
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# div = bs_obj.find("a", {"class":"ls_link"})
# a_1=div.findAll("a")

# %% [markdown]
# import urllib.request
#
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# for li in ul:
#     print(li)

# %% [markdown]
# import urllib.request
# import re
#
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# a_1=[]
# a_2=[]
# for li in ul:
#     a=re.sub(r"\n", "", li.text)
#     b=a.replace(r'\n', "")
#     a_1.append(b)
# for i in a_1:
#     if(i == ""):
#         pass
#     else :
#       a_2.append(i)
# a_2

# %% [markdown]
# import urllib.request
#
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# lis = ul.findAll("li")
# print(lis)

# %% [markdown]
# import urllib.request
#
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# lis = ul.findAll("li")
# for li in lis:
#     print(li)

# %% [markdown]
# import urllib.request
#
# url = "https://www.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# ul = bs_obj.find("ul", {"class":"list_nav type_fix"})
# lis = ul.findAll("li")
# for li in lis:
#     a_tag=li.find("a")
#     print(a_tag.text)

# %% [markdown]
# import urllib.request
# import bs4
# url = "https://news.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
#
# print(bs_obj)

# %% [markdown]
# import urllib.request
# import bs4
# url = "https://news.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
# newsnow_txarea = bs_obj.find("div", {"class" : "cjs_news_tw"})
# print(newsnow_txarea)

# %% [markdown]
# import urllib.request
# import bs4
# url = "https://news.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
# newsnow_txarea = bs_obj.findAll("div", {"class" : "cjs_news_tw"})
# print(newsnow_txarea)

# %% [markdown]
# import urllib.request
# import bs4
# url = "https://news.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
# newsnow_txarea = bs_obj.findAll("div", {"class" : "cjs_news_tw"})
#
# for i in newsnow_txarea:
#     div_tag=i.find("div")
#     print(div_tag.text)
#     p_tag=i.find("p")
#     print(p_tag.text)
#     print("===========================================================")

# %% [markdown]
# import urllib.request
# import bs4
# url = "https://news.naver.com"
# html = urllib.request.urlopen(url)
#
# bs_obj = bs4.BeautifulSoup(html, "html.parser")
# newsnow_txarea = bs_obj.findAll("div", {"class" : "cjs_news_tw"})
#
# for i in newsnow_txarea:
#     div_tag=i.find("div")
#     print(re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", div_tag.text))
#     p_tag=i.find("p")
#     print(re.sub(r"[^\uAC00-\uD7A30-9a-zA-Z\s]", "", p_tag.text))
#     print("===========================================================")

# %% [markdown]
# <div class="l-8WEmhJ" data-v-aeb56e5e=""><a class="_4nXvibcp" href="/w/%EC%8B%A0%ED%9D%A5%EC%97%AC%EA%B0%9D(%EA%B2%BD%EB%82%A8)" title="신흥여객(경남)" data-v-aeb56e5e="">신흥여객 고속관광</a></div>

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
#
# url_1 ="https://www.eosgo.io/"
#
# result = requests.get(url=url_1)
#
# bs_obj = BeautifulSoup(result.content, "html.parser")
# print(bs_obj)

# %% [markdown]
# <div class="mt-1 pt-10 grid gap-16 lg:grid-cols-3 lg:gap-x-5 lg:gap-y-6"><div><a href="news/eos-evm-a-bridge-between-eos-and-eth-ecosystems" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">EOS EVM: A Bridge Between EOS and Ethereum Ecosystems</h5><p class="font-normal text-gray-700 gray mb-2">In the world of blockchain technology, interoperability is an essential aspect that enables seamless communication betw...</p></a></div><div><a href="news/this-week-anticipation-and-excitement-levels-rising-for-eos" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">This Week: Anticipation and Excitement Levels Rising for EOS</h5><p class="font-normal text-gray-700 gray mb-2">Coming off quite an ...</p></a></div><div><a href="news/eden-guide-eden-election-process" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">Eden Guide: Eden Election Process</h5><p class="font-normal text-gray-700 gray mb-2">Now that you’ve learned about Eden on EOS, its ideology, and how it operates as a decentralized autonomous organization...</p></a></div><div><a href="news/eos-dev-strive-for-an-industry-edge" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">This Week: EOS Developments Strive for an Industry Edge</h5><p class="font-normal text-gray-700 gray mb-2">What an eventful week this past week has been, filled with exciting announcements, partnerships, and anticipation upcom...</p></a></div><div><a href="news/the-road-to-the-eos-evm-mainnet-launch" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">The Road to the EOS EVM Mainnet Launch</h5><p class="font-normal text-gray-700 gray mb-2">EOS, already a high-performance blockchain platform, has added a new feature called the EOS EVM (Ethereum Virtual Machi...</p></a></div><div><a href="news/eden-dao-origins-the-revolutionary-idea-of-more-equal-animals" class="news block p-6 max-w-lg bg-transparent rounded-lg  hover:no-underline border shadow-sm"><h5 class="mb-3 text-2md font-bold tracking-tight text-gray-900 dark">Eden DAO Origins: The Revolutionary Idea of More Equal Animals</h5><p class="font-normal text-gray-700 gray mb-2">"More Equal Animals" is a book written by the creator of the EOS blockchain, Daniel Larimer, that proposes a new social...</p></a></div></div>

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
#
# url_1 ="https://www.eosgo.io/"
#
# result = requests.get(url=url_1)
#
# bs_obj = BeautifulSoup(result.content, "html.parser")
# If_items = bs_obj.findAll("div", {"class":"mt-1 pt-10 grid gap-16 lg:grid-cols-3 lg:gap-x-5 lg:gap-y-6"})
# print(If_items)

# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
#
# url_1 ="https://www.eosgo.io/"
#
# result = requests.get(url=url_1)
#
# bs_obj = BeautifulSoup(result.content, "html.parser")
# link_1 = bs_obj.findAll("div", {"class":"mt-1 pt-10 grid gap-16 lg:grid-cols-3 lg:gap-x-5 lg:gap-y-6"})
# a_1=link_1[0].findAll('a')
# for i in a_1:
#     print(i['href'])

# %% [markdown]
# for i in a_1:
#     print(i['href'])

# %% [markdown]
# a_2=[]
# for i in a_1:
#     a_2.append(i['href'])
# a_2

# %% [markdown]
# for i in range(len(a_2)):
#     url_1 ="https://www.eosgo.io/"+str(a_2[i])
#     result = requests.get(url=url_1)
#     bs_obj = BeautifulSoup(result.content, "html.parser")
#     print(bs_obj)
#     print("******************************************************************************************************")
#     print("******************************************************************************************************")
#     print("******************************************************************************************************")
#     print("******************************************************************************************************")
#     print("******************************************************************************************************")
#     print("{}번째 작업을 마무리 하였습니다.".format(i+1))

# %% [markdown]
# # 엑셀로 저장 및 가져오기

# %%
import pandas as pd

# %%
inventors = pd.DataFrame(
    {
        'name': ['Nikola Tesla', 'Thomas Edison', 'Henry Ford'],
        'born': ['1856/07/10', '1847/02/11', '1863/07/30'],
        'died': ['1943/01/07', '1931/10/18', '1947/04/07'],
        'age': [86, 84, 83]
})

# %%
inventors
# Out:
#             name        born        died  age
# 0   Nikola Tesla  1856/07/10  1943/01/07   86
# 1  Thomas Edison  1847/02/11  1931/10/18   84
# 2     Henry Ford  1863/07/30  1947/04/07   83

# %%
inventors.to_excel('inventors.xlsx')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
inventors.to_excel('inventors_1.xlsx', index=False)

# %%
with pd.ExcelWriter('inventors.xlsx') as writer:
    inventors[inventors.name == 'Nikola Tesla'].to_excel(writer, sheet_name='Nikola Tesla')
    inventors[inventors.name == 'Thomas Edison'].to_excel(writer, sheet_name='Thomas Edison')
    inventors[inventors.name == 'Henry Ford'].to_excel(writer, sheet_name='Henry Ford')

# %%
with pd.ExcelWriter('inventors_1.xlsx') as writer:
    for name in inventors.name:
        inventors[inventors.name == f'{name}'].to_excel(writer, sheet_name=f'{name}')

# %%
a1=pd.read_excel('inventors_1.xlsx', sheet_name = 'Nikola Tesla')

# %%
a1
# Out:
#    Unnamed: 0          name        born        died  age
# 0           0  Nikola Tesla  1856/07/10  1943/01/07   86

# %%
a1 = a1.drop([a1.columns[0]], axis=1)

# %%
a1
# Out:
#            name        born        died  age
# 0  Nikola Tesla  1856/07/10  1943/01/07   86
